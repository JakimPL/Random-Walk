# %%
from randomwalk import RandomWalk

n = 1200
steps = 120
output_directory = "output"
data_filename = output_directory + "/walk_{0}.txt".format(n)

print("Generating a random walk...")
random_walk = RandomWalk(n)

print("A random walk generated successfully. Exporting data to {0} filename...".format(data_filename))
random_walk.export_walk(data_filename)

print("Exporting the plot to {0} directory...".format(output_directory))
random_walk.make_plot("output", steps)

print("Generating a sound wave to {0} directory...".format(output_directory))
random_walk.make_sound("output", steps)

print("Random walk generator ends.")
# Out:
# Generating a random walk...
# A random walk generated successfully. Exporting data to output/walk_1200.txt filename...
# Exporting the plot to output directory...
# Generating a sound wave to output directory...
# Random walk generator ends.
